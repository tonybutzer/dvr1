# %%
# %load read_playlist_xml.py
# wget http://dopey:32400/playlists/7111/items
import xml.etree.ElementTree as ET

def parse_plex_playlist(xml_file):
    """Parses a Plex playlist XML file and returns a list of media items.

    Args:
        xml_file (str): Path to the XML file.

    Returns:
        list: A list of dictionaries, each representing a media item with keys:
            - title: Title of the media item
            - key: Plex key of the media item (for further API interactions)
            # Add more keys as needed, e.g., duration, summary, etc.
    """

    tree = ET.parse(xml_file)
    root = tree.getroot()

    media_items = []
    for item in root.findall('Video') + root.findall('Track'):
        media_item = {
            'title': item.find('title').text,
            'key': item.find('key').text
        }
        # Add more fields as needed
        media_items.append(media_item)

    return media_items

# Example usage:
xml_file_path = './playlist_grammy.xml'
playlist_items = parse_plex_playlist(xml_file_path)

for item in playlist_items:
    print(f"Title: {item['title']}")
    print(f"Plex Key: {item['key']}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 34
#      32 # Example usage:
#      33 xml_file_path = './playlist_grammy.xml'
# ---> 34 playlist_items = parse_plex_playlist(xml_file_path)
#      36 for item in playlist_items:
#      37     print(f"Title: {item['title']}")
#
# Cell In[1], line 24, in parse_plex_playlist(xml_file)
#      21 media_items = []
#      22 for item in root.findall('Video') + root.findall('Track'):
#      23     media_item = {
# ---> 24         'title': item.find('title').text,
#      25         'key': item.find('key').text
#      26     }
#      27     # Add more fields as needed
#      28     media_items.append(media_item)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import xml.etree.ElementTree as ET

xml_file = './playlist_grammy.xml'
tree = ET.parse(xml_file)
root = tree.getroot()

# %%
dir(root)
# Out:
# ['__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'attrib',
#  'clear',
#  'extend',
#  'find',
#  'findall',
#  'findtext',
#  'get',
#  'insert',
#  'items',
#  'iter',
#  'iterfind',
#  'itertext',
#  'keys',
#  'makeelement',
#  'remove',
#  'set',
#  'tag',
#  'tail',
#  'text']

# %% [raw]
# print(root.tag)

# %%
print(len(root))
# Out:
# 124

# %%
print(root.text)

# %%
files=[]
for item in root.findall('Track'):
   # print(type(item))
    for thing in item.find('Media'):
        #print(type(thing))
        #print(ET.tostring(thing))
        mystr = ET.tostring(thing)
        # print(mystr)
        # print(type(mystr))
        realstr = mystr.decode('utf-8')
        mysplit0 = realstr.split('file=')[1]
        mysplit = mysplit0.split('\"')[1]
        #print(mysplit)
        ms = mysplit.replace('/music/', '/media/tony/22980B44725E901B/0_Music/')
        print(ms)
        files.append(ms)
        
        # print(realstr)
        # for child in thing.find('duration'):
        #     print(child.tag)
        # for mpart in thing.find('Part id'):
        #     print(ET.tostring(mpart))
        # mid = thing.find('id')
        # print(mid)
# Out:
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Dont Hurt Yourself (feat.Jack White).mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Stressed Out.mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Cheap Thrills (feat. Sean Paul).mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Hotline Bling.mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Hello.mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Love Yourself.mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Closer (feat. Halsey).mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Peter Pan.mp3
# ...

# %%
def write_m3u_playlist(files, filename="ultimate_grammy.m3u"):
    """Writes a list of files to an M3U playlist file.

    Args:
        files: A list of file paths to include in the playlist.
        filename: The name of the output M3U file. Defaults to "ultimate_sample.m3u".
    """

    with open(filename, "w") as f:
        for file in files:
            f.write(file + "\n")


write_m3u_playlist(files)

# %%
! cat ultimate_grammy.m3u
# Out:
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Dont Hurt Yourself (feat.Jack White).mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Stressed Out.mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Cheap Thrills (feat. Sean Paul).mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Hotline Bling.mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Hello.mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Love Yourself.mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Closer (feat. Halsey).mp3
# /media/tony/22980B44725E901B/0_Music/Compilations/Grammy/Various - 2017 Grammy Nominees/Various - Peter Pan.mp3
# ...

# %%
# !cp ultimate_grammy.m3u /tmp/grammy.m3u
